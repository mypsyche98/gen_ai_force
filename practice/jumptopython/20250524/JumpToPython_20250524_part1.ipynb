# %%
# 07-3 이터레이터와 제너레이터

for a in [1,2,3]:
  print(a)
# Out:
# 1
# 2
# 3

# %%
a = [1,2,3]
next(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-d8eae1318f96> in <cell line: 0>()
#       1 a = [1,2,3]
# ----> 2 next(a)
#
# TypeError: 'list' object is not an iterator

# %%
a = [1,2,3]
ia = iter(a)
print(type(ia))

print(next(ia))
print(next(ia))
print(next(ia))
print(next(ia))
# Out:
# <class 'list_iterator'>
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-3-71fefb3a4eb9> in <cell line: 0>()
#       6 print(next(ia))
#       7 print(next(ia))
# ----> 8 print(next(ia))
#
# StopIteration:

# %%
a = [1,2,3]
ia = iter(a)
for i in ia:
  print(i)

# doing nothing
for i in ia:
  print(i)
# Out:
# 1
# 2
# 3

# %%
class MyIterator:
  def __init__(self,data):
    self.data = data
    self.position = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.position  >= len(self.data):
      raise StopIteration
    result = self.data[self.position]
    self.position += 1
    return result

if __name__ == "__main__":
  i = MyIterator([1,2,3])
  for item in i:
    print(item)
# Out:
# 1
# 2
# 3

# %%
class ReserveIterator:
  def __init__(self,data):
    self.data = data
    self.position = len(self.data)-1

  def __iter__(self):
    return self

  def __next__(self):
    if self.position  < 0:
      raise StopIteration
    result = self.data[self.position]
    self.position -= 1
    return result

if __name__ == "__main__":
  i = ReserveIterator([1,2,3])
  for item in i:
    print(item)
# Out:
# 3
# 2
# 1

# %%
def mygen():
  yield 'a'
  yield 'b'
  yield 'c'

  g = mygen()
  print(type(g))

  print(next(g))

# %%
def mygen():
  for i in range(1,1000):
    result = i*i
    yield result

gen = mygen()

print(next(gen))
print(next(gen))
print(next(gen))

gen = (i * i for i in range(1,100))
# Out:
# 1
# 4
# 9

# %%
class MyIterator:
  def __init__(self):
    self.data = 1

  def __iter__(self):
    return self

  def __next__(self):
    result = self.data * self.data
    self.data += 1
    if ( self.data >= 1000 ):
      raise StopIteration
    return result

myIter = MyIterator()
print(next(myIter))
print(next(myIter))
print(next(myIter))
# Out:
# 1
# 4
# 9

# %%
import time

def longtime_job():
  print("job start")
  time.sleep(1)
  return "done"

list_job = [longtime_job() for i in range(5)]
print(list_job[0])
# Out:
# job start
# job start
# job start
# job start
# job start
# done

# %%
import time

def longtime_job():
  print("job start")
  time.sleep(1)
  return "done"

list_job = (longtime_job() for i in range(5))
print(next(list_job))
# Out:
# job start
# done

# %%
# 07-4 파이썬 타입 어노테이션

a = 1
print(type(a))

a = "a"
print(type(a))
# Out:
# <class 'int'>
# <class 'str'>

# %%
num:int = 1

def add(a:int, b:int) -> int:
  return a+b

print(type(num))

print(add(1,2))
print(add("a","b"))
# Out:
# <class 'int'>
# 3
# ab

# %%
# 08-1 정규 표현식 살펴보기

data = """
park 800905-1049118
kim 700905-1059119
"""

result = []
for line in data.split("\n"):
  word_result = []
  for word in line.split(" "):
    if len(word) == 14 and word[:6].isdigit() and word[7:].isdigit():
      word = word[:6] + "-" + "*"*7
    word_result.append(word)
  result.append(" ".join(word_result))
print("\n".join(result))
# Out:
# park 800905-*******
# kim 700905-*******

# %%
import re

data = """
park 800905-1049118
kim  700905-1059119
"""

pat = re.compile("(\d{6})[-]\d{7}")
print(pat.sub("\g<1>-*******", data))
# Out:
# park 800905-*******
# kim  700905-*******

# %%
# 08-2 정규표현식 시작하기

import re
p = re.compile("ab*")

# %%
import re
p = re.compile('[a-z]+')

m = p.match("python")
print(m)

m = p.match("3 python")
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>
# None

# %%
p = re.compile('[a-z]+')
data = """
park 800905-1049118
kim  700905-1059119
"""

m = p.match( data )
if m:
    print('Match found: ', m.group())
else:
    print('No match')
# Out:
# No match

# %%
m = p.search("python")
print(m)

m = p.search("3 python")
print(m)
# Out:
# <re.Match object; span=(0, 6), match='python'>
# <re.Match object; span=(2, 8), match='python'>

# %%
result = p.findall("life is too short")
print(result)
# Out:
# ['life', 'is', 'too', 'short']

# %%
result = p.finditer("life is too short")
print(result)

for r in result:
  print(r)
# Out:
# <callable_iterator object at 0x7f2349dfafb0>
# <re.Match object; span=(0, 4), match='life'>
# <re.Match object; span=(5, 7), match='is'>
# <re.Match object; span=(8, 11), match='too'>
# <re.Match object; span=(12, 17), match='short'>

# %%
m = p.match("python")
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# python
# 0
# 6
# (0, 6)

# %%
m = p.search("3 python")
print(m.group())
print(m.start())
print(m.end())
print(m.span())
# Out:
# python
# 2
# 8
# (2, 8)

# %%
m = re.match('[a-z]+', "python")

# %%
import re
p = re.compile('a.b')
m = p.match('a\nb')
print(m)
# Out:
# None

# %%
p = re.compile('a.b', re.DOTALL)
m = p.match('a\nb')
print(m)
# Out:
# <re.Match object; span=(0, 3), match='a\nb'>

# %%
p = re.compile('[a-z]+', re.I)
print(p.match('python'))
print()
print(p.match('Python'))
print()
print(p.match('PYTHON'))
# Out:
# <re.Match object; span=(0, 6), match='python'>
#
# <re.Match object; span=(0, 6), match='Python'>
#
# <re.Match object; span=(0, 6), match='PYTHON'>

# %%
p = re.compile("^python\s\w+")

data = """python one
life is too short
python two
you need python
python three"""

print(p.findall(data))

p = re.compile("^python\s\w+", re.MULTILINE)
print(p.findall(data))
# Out:
# ['python one']
# ['python one', 'python two', 'python three']

# %%
charref = re.compile(r'&[#](0[0-7]+|[0-9]+|x[0-9a-fA-F]+);')

charref = re.compile(r"""
 &[#]                # Start of a numeric entity reference
 (
     0[0-7]+         # Octal form
   | [0-9]+          # Decimal form
   | x[0-9a-fA-F]+   # Hexadecimal form
 )
 ;                   # Trailing semicolon
""", re.VERBOSE)

# %%
p = re.compile("Crow|Servo")
m = p.match("CrowHello")
print(m)
# Out:
# <re.Match object; span=(0, 4), match='Crow'>

# %%
print(re.search('^Life', 'Life is too short'))
print(re.search('^Life', 'My Life'))
# Out:
# <re.Match object; span=(0, 4), match='Life'>
# None

# %%
print(re.search('short$', 'Life is too short'))
print(re.search('short$', 'Life is too short, you need python'))
# Out:
# <re.Match object; span=(12, 17), match='short'>
# None

# %%
p = re.compile(r'\bclass\b')
print(p.search('no class at all'))
print(p.search('the declassified algorithm'))
print(p.search('one subclass is'))
# Out:
# <re.Match object; span=(3, 8), match='class'>
# None
# None

# %%
p = re.compile(r'\Bclass\B')
print(p.search('no class at all'))
print(p.search('the declassified algorithm'))
print(p.search('one subclass is'))
# Out:
# None
# <re.Match object; span=(6, 11), match='class'>
# None

# %%
p = re.compile('(ABC)+')
m = p.search("ABCABCABC OK?")
print(m)
print(m.group())
# Out:
# <re.Match object; span=(0, 9), match='ABCABCABC'>
# ABCABCABC

# %%
p = re.compile(r"\w+\s+\d+[-]\d+[-]\d+")
m = p.search("park 010-1234-1234")
print(m)
# Out:
# <re.Match object; span=(0, 18), match='park 010-1234-1234'>

# %%
p = re.compile(r"(\w+)\s+\d+[-]\d+[-]\d+")
m = p.search("park 010-1234-1234")
print(m.group(1))
# Out:
# park

# %%
p = re.compile(r"(\w+)\s+(\d+[-]\d+[-]\d+)")
m = p.search("park 010-1234-1234")
print(m.group(2))
# Out:
# 010-1234-1234

# %%
p = re.compile(r"(\w+)\s+((\d+)[-]\d+[-]\d+)")
m = p.search("park 010-1234-1234")
print(m.group(3))
# Out:
# 010

# %%
p = re.compile(r'(\b\w+)\s+\1')
print(p.search('Paris is the the sprint').group())
# Out:
# the the

# %%
p = re.compile(r"(?P<name>\w+)\s+((\d+)[-]\d+[-]\d+)")
m = p.search("park 010-1234-1234")
print(m.group("name"))
# Out:
# park

# %%
p = re.compile(r"(?P<word>\b\w+)\s+(?P=word)")
print(p.search("Paris is the the spring").group())
# Out:
# the the

# %%
  p = re.compile('.+(?=:)')
  m = p.search("http://google.com")
  print(m.group())     # http
# Out:
# http

# %%
p = re.compile('(blue|white|red)')
print(p.sub('colour', 'blue socks and red shoes'))
# Out:
# colour socks and colour shoes

# %%
p = re.compile(r"(?P<name>\w+)\s+(?P<phone>(\d+)[-]\d+[-]\d+)")
print(p.sub("\g<phone> \g<name>", "park 010-1234-1234"))
# Out:
# 010-1234-1234 park

# %%
def hexrepl(match):
  value = int(match.group())
  return hex(value)

p = re.compile(r'\d+')
print(p.sub(hexrepl, 'Call 64590 for printing, 49152 for user code.'))
# Out:
# Call 0xfc4e for printing, 0xc000 for user code.

# %%
s = '<html><head><title>Title</title>'
print(len(s))
print(re.match('<.*>', s).span())   # greedy
print(re.match('<.*>', s).group())  # greedy
print()
print(re.match('<.*?>', s).group()) # non-greedy
# Out:
# 32
# (0, 32)
# <html><head><title>Title</title>
#
# <html>
