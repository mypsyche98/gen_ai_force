# %%
import plotly.graph_objects as go
import plotly.express as px

# page 5

df = px.data.tips()

fig = px.histogram(df, x='sex', y="tip", histfunc="sum", facet_col="smoker", width=600, height=400)
fig.update_xaxes(showline=True, linewidth=3, linecolor='black')
fig.update_yaxes(showline=True, linewidth=3, linecolor='red')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 6

df = px.data.tips()

fig = px.histogram(df, x='sex', y="tip", histfunc="sum", facet_col="smoker", width=600, height=400)
fig.update_xaxes(showline=True, linewidth=3, linecolor='black', col=1)
fig.update_yaxes(showline=True, linewidth=3, linecolor='red', col=1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 9

df = px.data.tips()

fig = px.histogram(df, x='sex', y="tip", histfunc="sum", facet_col="smoker", width=600, height=400)
fig.update_xaxes(showline=True, linewidth=3, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=3, linecolor='red', mirror=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 12

df = px.data.iris()

fig = px.scatter(df, x='sepal_width', y="sepal_length", facet_col="species", width=600, height=400)
fig.update_xaxes(showgrid=True, minor_showgrid=True)
fig.update_yaxes(showgrid=True, minor_showgrid=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 13

df = px.data.iris()

fig = px.scatter(df, x='sepal_width', y="sepal_length", facet_col="species", width=600, height=400)
fig.update_xaxes(showgrid=True, minor_showgrid=True, col=1)
fig.update_yaxes(showgrid=True, minor_showgrid=True, col=1)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 13

df = px.data.iris()

fig = px.scatter(df, x='sepal_width', y="sepal_length", facet_col="species", width=1000, height=600)
fig.update_xaxes(minor_showgrid=True, griddash='dash', gridcolor='black', minor_griddash="dot", minor_gridcolor="LightPink")
fig.update_yaxes(minor_showgrid=True, griddash='dash', gridcolor='black', minor_griddash="dot", minor_gridcolor="LightPink")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 18

fig = px.scatter(x=[0,1,2,3,4],y=[0,1,4,9,16], size=[20]*5, width=800, height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 19

fig = px.scatter(x=[0,1,2,3,4],y=[0,1,4,9,16], size=[20]*5, width=800, height=400)

fig.add_trace(go.Scatter(x=[0,1,2,3,4],y=[0,1,4,9,16]))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 21

fig = go.Figure()
fig.update_layout(width=800, height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 22

import numpy as npy
npy.random.seed(1)

N = 100
random_x = npy.linspace(0,1,N)
random_y0 = npy.random.randn(N) + 5
random_y1 = npy.random.randn(N)
random_y2 = npy.random.randn(N) - 5

fig = go.Figure()
fig.update_layout(width=800, height=500)

fig.add_trace(go.Scatter(x=random_x, y=random_y0, mode="lines", name="lines"))
fig.add_trace(go.Scatter(x=random_x, y=random_y1, mode="lines+markers", name="lines+markers"))
fig.add_trace(go.Scatter(x=random_x, y=random_y2, mode="markers", name="markers"))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 32

from plotly.subplots import make_subplots

fig = make_subplots(rows=1,cols=2)
fig.update_layout(width=1000,height=500)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[4,5,6]),
    row=1, col=1,
)

fig.add_trace(
    go.Scatter(x=[20,30,40],y=[50,60,70]),
    row=1, col=2,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 33

fig = make_subplots(rows=2,cols=2)
fig.update_layout(width=1000,height=500)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[4,5,6]),
    row=1, col=1,
)

fig.add_trace(
    go.Scatter(x=[20,30,40],y=[50,60,70]),
    row=1, col=2,
)

fig.add_trace(
    go.Scatter(x=[300,400,500],y=[600,700,800]),
    row=2, col=1,
)

fig.add_trace(
    go.Scatter(x=[4000,5000,6000],y=[7000,8000,9000]),
    row=2, col=2,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 35

fig = make_subplots(rows=2,cols=2,
                    subplot_titles=("Plot 1","Plot 2", "Plot 3", "Plot 4"))
fig.update_layout(width=1000,height=500)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[4,5,6]),
    row=1, col=1,
)

fig.add_trace(
    go.Scatter(x=[20,30,40],y=[50,60,70]),
    row=1, col=2,
)

fig.add_trace(
    go.Scatter(x=[300,400,500],y=[600,700,800]),
    row=2, col=1,
)

fig.add_trace(
    go.Scatter(x=[4000,5000,6000],y=[7000,8000,9000]),
    row=2, col=2,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 38

fig = make_subplots(rows=2,cols=2,
                    column_widths=[0.7,0.3], row_heights=[0.7,0.3])
fig.update_layout(width=1000,height=500)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[4,5,6]),
    row=1, col=1,
)

fig.add_trace(
    go.Scatter(x=[20,30,40],y=[50,60,70]),
    row=1, col=2,
)

fig.add_trace(
    go.Scatter(x=[300,400,500],y=[600,700,800]),
    row=2, col=1,
)

fig.add_trace(
    go.Scatter(x=[4000,5000,6000],y=[7000,8000,9000]),
    row=2, col=2,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 40

fig = make_subplots(rows=3,cols=1,
                    shared_xaxes=True)
fig.update_layout(width=600,height=500)

fig.add_trace(
    go.Scatter(x=[0,1,2],y=[10,11,12]),
    row=3, col=1,
)

fig.add_trace(
    go.Scatter(x=[2,3,4],y=[100,110,120]),
    row=2, col=1,
)

fig.add_trace(
    go.Scatter(x=[3,4,5],y=[1000,1100,1200]),
    row=1, col=1,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 42

fig = make_subplots(rows=2,cols=2,
                    specs=[[{},{}],
                           [{"colspan":2}, None]],
                    subplot_titles=("First", "Second", "Third")
                    )

fig.update_layout(width=600,height=500)

fig.add_trace(
    go.Scatter(x=[1,2],y=[1,2]),
                row=1, col=1,
            )

fig.add_trace(
    go.Scatter(x=[1,2],y=[1,2]),
                row=1, col=2,
            )

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[2,1,2]),
                row=2, col=1,
            )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 45

fig = make_subplots(
    specs=[[{"secondary_y":True}]]
)

fig.update_layout(width=600,height=500)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[40,50,60], name="yaxis"),
                secondary_y=False,
            )

fig.add_trace(
    go.Scatter(x=[2,3,4],y=[4,5,6], name="yaxis2"),
                secondary_y=True
            )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 49

fig = make_subplots(
    rows=2,
    cols=2,
    specs=[[{"secondary_y":True},{"secondary_y":True}],
           [{"secondary_y":True},{"secondary_y":True}]
    ]
)

fig.update_layout(width=600,height=500)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[2,52,62], name="yaxis"),
    row=1, col=1,
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[40,50,60], name="yaxis2"),
    row=1, col=1,
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[2,52,62], name="yaxis3"),
    row=1, col=2,
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[40,50,60], name="yaxis4"),
    row=1, col=2,
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[2,52,62], name="yaxis5"),
    row=2, col=1,
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[40,50,60], name="yaxis6"),
    row=2, col=1,
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[2,52,62], name="yaxis7"),
    row=2, col=2,
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=[1,2,3],y=[40,50,60], name="yaxis8"),
    row=2, col=2,
    secondary_y=True,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 52

df = px.data.tips()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# page 53

df = px.data.tips()

fig = px.scatter(df, x="total_bill", y="tip", color="sex")
fig.update_layout(width=600,height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 52

df = px.data.tips()
print(df.head())
print()
Female = df.loc[df["sex"]=="Female",:]
print(Female.head())
print()
Male = df.loc[df["sex"]=="Male",:]
print(Male.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3
#
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# ...

# %%
# page 56

df = px.data.tips()

Female
fig = go.Figure()
fig.update_layout(width=600,height=400)

fig.add_trace(
    go.Scatter(
        x=Female.total_bill,
        y=Female.tip,
        mode="markers",
        name="Female",
    )
)

fig.add_trace(
    go.Scatter(
        x=Male.total_bill,
        y=Male.tip,
        mode="markers",
        name="Male",
    )
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 60

df = px.data.tips()

fig = px.scatter(df,
                 x="total_bill",
                 y="tip",
                 color="sex"
)

fig.update_layout(showlegend=False,
                  width=600,height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 63

df = px.data.tips()

fig = px.scatter(df,
                 x="total_bill",
                 y="tip",
                 color="sex"
)

fig.update_layout(
    legend_yanchor="top",
    legend_y=0.99,
    legend_xanchor="left",
    legend_x=0.01,
    width=600,height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 65

df = px.data.tips()

fig = px.scatter(df,
                 x="total_bill",
                 y="tip",
                 color="sex"
)

fig.update_layout(
    legend_orientation="h",
    legend_entrywidth=70,
    legend_yanchor="top",
    legend_y=0.99,
    legend_xanchor="left",
    legend_x=0.01,
    width=600,height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 67

df = px.data.tips()

fig = px.scatter(df,
                 x="total_bill",
                 y="tip",
                 color="sex"
)

fig.update_layout(
    legend_title_text="성별",
    legend_title_font_family="Times New Roman",
    legend_title_font_color="red",
    legend_title_font_size=20,
    legend_font_family="Courier",
    legend_font_size=12,
    legend_font_color="black",
    legend_bgcolor="LightSteelBlue",
    legend_bordercolor="Black",
    legend_borderwidth=2,
    width=600,height=400)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 70

import plotly.io as pio

pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
# page 71

df = px.data.gapminder()
df_2007 = df.query("year==2007")

for template in ["plotly", "plotly_white", "plotly_dark", "ggplot2", "seaborn", "simple_white", "none"]:
  fig = px.scatter(
      df_2007,
      x="gdpPercap",
      y="lifeExp",
      size="pop",
      color="continent",
      log_x=True,
      size_max=60,
      template=template,
      title="Gapminder 2007: '%s' theme" % template,
      width=500,
      height=400,
  )
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 76

watermark_template = go.layout.Template(
    layout_annotations=[
        dict(
            name="watermark_template",
            text="secret",
            textangle=-30,
            opacity=0.1,
            font=dict(
                color="black",
                size=100,
            ),
            xref="paper",
            yref="paper",
            x=0.5,
            y=0.5,
            showarrow=False,
        )
    ]
)

# %%
# page 77

fig = go.Figure()
fig.update_layout(width=600,height=400)

fig.add_trace(
    go.Scatter(
        x=[0,1,2,3,4,5],
        y=[1.5,1,1.3,0.7,0.8,0.8]
    )
)

fig.update_layout(
    template=watermark_template
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# page 78

df = px.data.gapminder()
df_2007 = df.query("year==2007")

fig = px.scatter(
    df_2007,
    x="gdpPercap",
    y="lifeExp",
    size="pop",
    color="continent",
    log_x=True,
    width=700,
    height=400,
)
fig.update_layout(template=watermark_template)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
