# %%
# !pip install -q streamlit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 54.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.6 MB/s eta 0:00:00

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.2.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Downloading pyngrok-7.2.8-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.2.8

# %%
# !ngrok authtoken 2xhZXOxNBsBmIZsb0hWND79RIyZ_3TKnTaRQAbv3dBVjTxVk7
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# %%writefile ngrok_test.py
import streamlit as st

x = st.slider('Select a value')
st.write(x, 'squared is', x * x)
# Out:
# Writing ngrok_test.py

# %%
# !streamlit run ngrok_test.py &>/content/logs.txt &

# %%
from pyngrok import ngrok

publ_url = ngrok.connect(addr='8501')
print(publ_url)
# Out:
# NgrokTunnel: "https://317b-34-168-155-138.ngrok-free.app" -> "http://localhost:8501"

# %%
# !ps -ef | grep streamlit
# Out:
# root        4074       1  2 02:33 ?        00:00:01 /usr/bin/python3 /usr/local/bin/streamlit run ngrok_test.py
# root        4254     210  0 02:33 ?        00:00:00 /bin/bash -c ps -ef | grep streamlit
# root        4256    4254  0 02:33 ?        00:00:00 grep streamlit

# %%
# !kill -9 4074

# %%
# !ps -ef | grep ngrok
# Out:
# root        4122     210  1 02:33 ?        00:00:00 /root/.config/ngrok/ngrok start --none --log stdout
# root        4282     210  0 02:33 ?        00:00:00 /bin/bash -c ps -ef | grep ngrok
# root        4284    4282  0 02:33 ?        00:00:00 grep ngrok

# %%
# !kill -9 4122
