# %%
name = "minsu"
score = 90
print("%s의 점수는 %d 점입니다." % (name, score))
print("{}의 점수는 {} 점입니다.".format(name, score))
print(f"{name}의 점수는 {score} 점입니다.")
#-------------------
data = 3
fmt = "{{ {} }}".format(data)
print(fmt)
#-------------------
fmt = f"{{ {data} }}"
print(fmt)
#-------------------
a = 3
mystr = f"{a:02d}"
print(mystr)
#-------------------
symbol = "BTCUSDT"
print(f"{symbol:10}")
#-------------------
a = 3.141592
mystr = f"{a:6.2f}"
print(mystr)
#-------------------
a = "hello"
b = ["hello", "python"]

print(id(a))
print(id(b))
print(id(a), id(b[0]))
#-------------------
a = "python2"
b = "python3"
print(id(a))
print(id(b))
#-------------------
a = ["python2","python3"]
print(id(a))
a.append("python4")
a
print(id(a))
print(id(a[0]))
print(id(a[1]))
print(id(a[1]))
#-------------------
a = 1000
b = 1000
a == b
a is b
print(id(a), id(b))
#-------------------
even_num = [ ]
for i in range(10):
  if i % 2 == 0:
    even_num.append(i)

print(even_num)
#-------------------
even_num = [i for i in range(10) if i % 2 == 0]
print(even_num)
#-------------------
odd_num = [i for i in range(10) if i % 2 == 1]
print(odd_num)
#-------------------
pow2_nums = [i*i for i in range(10)]
#-------------------
a = 1,2
b = (1,2)
print(a, type(a))
print(b, type(b))
#-------------------
data = (1,2,3)
n1, n2, n3 = data
print(n1, n2, n3)
#-------------------
data = (1,2,3)
n1 = data[0]
n2 = data[1]
n3 = data[2]
print(n1, n2, n3)
#-------------------
scores = (1,2,3,4,5,6)
low, *others, high = scores
print(others)
#-------------------
def foo():
  return 1,2,3

val = foo()
print(type(val))
#-------------------
def hap(num1, num2, num3, num4):
  return num1+num2+num3+num4

scores = (1,2,3,4)
result = hap(scores[0], scores[1], scores[2], scores[3])
print(result)

result = hap(*scores)
print(result)
#-------------------
name = ['merona', 'gugucon']
price = [500, 1000]

z = zip(name, price)
print(list(z))
#-------------------
for n,p in zip(name,price):
  print(n, p)
#-------------------
아이스크림1 = {"메로나":500, "구구콘":1000}
아이스크림2 = dict(메로나=500, 구구콘=1000)
아이스크림3 = dict([("메로나",500), ("구구콘",1000)])
#-------------------
name = ['merona', 'gugucon']
price = [500, 1000]

icecream = dict(zip(name, price))
print(icecream)
#-------------------
data = {}

ret = data.setdefault('a', 0)
print(ret, data)

ret = data.setdefault('a', 1)
print(ret, data)
#-------------------
data = ["BTC", "BTC", "XRP", "ETH", "ETH", "ETH"]
for k in set(data):
  count = data.count(k)
  print(k, count)
#-------------------
name = ['merona', 'gugucon']
price = [500, 1000]

icecream = {k:v for k,v in zip(name, price)}
print(icecream)
#-------------------
icecream = {k:v*2 for k,v in zip(name, price)}
print(icecream)
#-------------------
name = ['merona', 'gugucon', 'bibibig']
price = [500, 1000, 600]

icecream = {k:v for k,v in zip(name, price) if v < 1000}
print(icecream)
#-------------------
class Book:
  def __init__(self, title, price):
    self.title = title
    self.price = price

mybook = Book("파이선을 이용한 비트코인 자동매매", 27000)
print(mybook.title, mybook.price)

mybook2 = ("파이선을 이용한 비트코인 자동매매", 27000)
print(mybook2[0], mybook2[1])
#-------------------
from collections import namedtuple
Book = namedtuple('Book', ['title','price'])
mybook3 = Book("파이선을 이용한 비트코인 자동매매", 27000)
print(mybook3.title, mybook3.price)
print(mybook3[0], mybook3[1])
#mybook3.price = 25000
#-------------------
def print_book(title, price):
  print(title, price)

print_book(*mybook3)
# Out:
# minsu의 점수는 90 점입니다.
# minsu의 점수는 90 점입니다.
# minsu의 점수는 90 점입니다.
# { 3 }
# { 3 }
# 03
# BTCUSDT
#   3.14
# 135478883255856
# 135477492301312
# 135478883255856 135478883255856
# 135478902626032
# 9737312
# 135477492298432
# 135477492298432
# 135478902626032
# 9737312
# 9737312
# 135477491914352 135477491914256
# [0, 2, 4, 6, 8]
# [0, 2, 4, 6, 8]
# [1, 3, 5, 7, 9]
# (1, 2) <class 'tuple'>
# (1, 2) <class 'tuple'>
# 1 2 3
# 1 2 3
# [2, 3, 4, 5]
# <class 'tuple'>
# 10
# 10
# [('merona', 500), ('gugucon', 1000)]
# merona 500
# gugucon 1000
# {'merona': 500, 'gugucon': 1000}
# 0 {'a': 0}
# 0 {'a': 0}
# BTC 2
# ETH 3
# XRP 1
# {'merona': 500, 'gugucon': 1000}
# {'merona': 1000, 'gugucon': 2000}
# {'merona': 500, 'bibibig': 600}
# 파이선을 이용한 비트코인 자동매매 27000
# 파이선을 이용한 비트코인 자동매매 27000
# 파이선을 이용한 비트코인 자동매매 27000
# 파이선을 이용한 비트코인 자동매매 27000
# 파이선을 이용한 비트코인 자동매매 27000
