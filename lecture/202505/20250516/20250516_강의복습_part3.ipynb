# %%
#------------
print('page78','-'*30)

def num_gen():
  for i in range(3):
    yield i

g = num_gen()

num1 = next(g)
num2 = next(g)
num3 = next(g)

print(num1, num2, num3)

#------------
print('page80','-'*30)

print(g, type(g))

#------------
print('page80','-'*30)

g = num_gen()

print(next(g))
print(next(g))
print(next(g))
#print(next(g)) #StopIteration:

#------------
print('page81','-'*30)
g = num_gen()
for i in g:
  print(i)

#------------
print('page85','-'*30)
def 빵만들기(n):
  빵쟁반 = []
  for i in range(n):
      빵 = "빵" + str(i)
      print("{} 만듦".format(빵))
      빵쟁반.append(빵)
  return 빵쟁반

def 빵포장(빵):
  print("{} 포장완료".format(빵))

for i in 빵만들기(100):
  빵포장(i)

#------------
print('page86','-'*30)
def 빵만들기(n):
  빵쟁반 = []
  for i in range(n):
      빵 = "빵" + str(i)
      print("{} 만듦".format(빵))
      yield 빵


def 빵포장(빵):
  print("{} 포장완료".format(빵))

for i in 빵만들기(100):
  빵포장(i)
# Out:
# page78 ------------------------------
# 0 1 2
# page80 ------------------------------
# <generator object num_gen at 0x7de8b2042330> <class 'generator'>
# page80 ------------------------------
# 0
# 1
# 2
# page81 ------------------------------
# 0
# 1
# 2
# page85 ------------------------------
# 빵0 만듦
# 빵1 만듦
# 빵2 만듦
# 빵3 만듦
# 빵4 만듦
# 빵5 만듦
# 빵6 만듦
# 빵7 만듦
# 빵8 만듦
# 빵9 만듦
# 빵10 만듦
# 빵11 만듦
# 빵12 만듦
# 빵13 만듦
# 빵14 만듦
# 빵15 만듦
# 빵16 만듦
# 빵17 만듦
# 빵18 만듦
# 빵19 만듦
# 빵20 만듦
# 빵21 만듦
# 빵22 만듦
# 빵23 만듦
# 빵24 만듦
# 빵25 만듦
# 빵26 만듦
# 빵27 만듦
# 빵28 만듦
# 빵29 만듦
# 빵30 만듦
# 빵31 만듦
# 빵32 만듦
# 빵33 만듦
# 빵34 만듦
# 빵35 만듦
# 빵36 만듦
# 빵37 만듦
# 빵38 만듦
# 빵39 만듦
# 빵40 만듦
# 빵41 만듦
# 빵42 만듦
# 빵43 만듦
# 빵44 만듦
# 빵45 만듦
# 빵46 만듦
# 빵47 만듦
# 빵48 만듦
# 빵49 만듦
# 빵50 만듦
# 빵51 만듦
# 빵52 만듦
# 빵53 만듦
# 빵54 만듦
# 빵55 만듦
# 빵56 만듦
# 빵57 만듦
# 빵58 만듦
# 빵59 만듦
# 빵60 만듦
# 빵61 만듦
# 빵62 만듦
# 빵63 만듦
# 빵64 만듦
# 빵65 만듦
# 빵66 만듦
# 빵67 만듦
# 빵68 만듦
# 빵69 만듦
# 빵70 만듦
# 빵71 만듦
# 빵72 만듦
# 빵73 만듦
# 빵74 만듦
# 빵75 만듦
# 빵76 만듦
# 빵77 만듦
# 빵78 만듦
# ...
