# %%
# !pip install contextualized-topic-models
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 90.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 13.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 119.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pyldavis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 24.9 MB/s eta 0:00:00
# ...

# %%
# Colab에 Mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab_light_220429.sh
# %cd ..
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91 (from 1)
# Receiving objects: 100% (138/138), 1.72 MiB | 12.91 MiB/s, done.
# Resolving deltas: 100% (65/65), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.6/496.6 kB 35.2 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2025-08-07 12:09:30--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.142.24, 104.192.142.26, 104.192.142.25, ...
# ...

# %%
# !wget https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt
# Out:
# --2025-08-07 12:11:33--  https://raw.githubusercontent.com/lovit/soynlp/master/tutorials/2016-10-20.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43694449 (42M) [text/plain]
# Saving to: ‘2016-10-20.txt’
#
# 2016-10-20.txt      100%[===================>]  41.67M   158MB/s    in 0.3s
#
# 2025-08-07 12:11:36 (158 MB/s) - ‘2016-10-20.txt’ saved [43694449/43694449]

# %%
# !head -n 1 2016-10-20.txt

# %%
# !head -n 3 2016-10-20.txt
# Out:
#
# 19  1990  52 1 22
# ...

# %%
# !head -n 5 2016-10-20.txt
# Out:
#
# 19  1990  52 1 22
# ...

# %%
# !head -n 20 2016-10-20.txt
# Out:
#
# 19  1990  52 1 22
# ...

# %%
text_file = "2016-10-20.txt"

# %%
from contextualized_topic_models.models.ctm import CombinedTM
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation, bert_embeddings_from_list
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
from sklearn.feature_extraction.text import CountVectorizer
from konlpy.tag import Mecab
from tqdm import tqdm

# %% [markdown]
# ## 전처리

# %%
documents = [line.strip() for line in open(text_file, encoding="utf-8").readlines()]

# %%
documents[:5]
# Out:
# ['',
#  '19  1990  52 1 22',
# ...

# %%
not '19  1990  52 1 22'.replace(' ', '').isdecimal()
# Out:
# False

# %%
preprocessed_documents = []

for line in tqdm(documents):
  # 빈 문자열이거나 숫자로만 이루어진 줄은 제외
  if line and not line.replace(' ', '').isdecimal():
    preprocessed_documents.append(line)
# Out:
# 100%|██████████| 30091/30091 [00:00<00:00, 140377.57it/s]

# %%
len(preprocessed_documents)
# Out:
# 27540

# %%
class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, sent):
        word_tokens = self.tagger.morphs(sent)
        result = [word for word in word_tokens if len(word) > 1]
        return result

# %%
custom_tokenizer = CustomTokenizer(Mecab())

# %%
vectorizer = CountVectorizer(tokenizer=custom_tokenizer, max_features=3000)

# %%
train_bow_embeddings = vectorizer.fit_transform(preprocessed_documents)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
print(train_bow_embeddings.shape)
# Out:
# (27540, 3000)

# %%
vocab = vectorizer.get_feature_names_out()
id2token = {k: v for k, v in zip(range(0, len(vocab)), vocab)}

# %%
len(vocab)
# Out:
# 3000

# %%
train_contextualized_embeddings = bert_embeddings_from_list(preprocessed_documents, "sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens", max_seq_length=512)  # 이 부분을 추가합니다.
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# ...

# %%
qt = TopicModelDataPreparation()

training_dataset = qt.load(train_contextualized_embeddings, train_bow_embeddings, id2token)

# %% [markdown]
# ## Combined TM 학습하기
# 이제 토픽 모델을 학습합니다. 여기서는 하이퍼파라미터에 해당하는 토픽의 개수(n_components)로는 50개를 선정합니다.

# %%
ctm = CombinedTM(bow_size=len(vocab), contextual_size=768, n_components=50, num_epochs=20)
ctm.fit(training_dataset)
# Out:
# Epoch: [20/20]	 Seen Samples: [550400/550800]	Train Loss: 850.4276046398074	Time: 0:00:07.623272: : 20it [02:29,  7.46s/it]
# 100%|██████████| 431/431 [00:05<00:00, 76.97it/s]

# %%
ctm.get_topics(5)
# Out:
# defaultdict(list,
#             {0: ['시장', '나노', '네이버', '패널', '삼성'],
#              1: ['영화', '사랑', '배우', '때문', '차태현'],
#              2: ['필리핀', '중국', '테르', '회담', '베이징'],
#              3: ['지상파', '방송', '방송사', '가이드라인', '산정'],
#              4: ['다운', '재킷', '제공', '이벤트', '소재'],
#              5: ['에서', '다고', '으로', '남북', '국정원'],
#              6: ['지만', '사람', '이경규', '강호동', '도우'],
#              7: ['교육', '교육청', '학생', '진로', '지원'],
#              8: ['뉴시스', '영상', '언론', '사진', '공감'],
#              9: ['김정은', '장관', '북한', '수단', '위협'],
#              10: ['공시', '임신', '투데이', '왕자', '머니'],
#              11: ['기업', '경제', '연봉제', '성과', '중소기업'],
#              12: ['는다는', '연합뉴스', '부여', '들어갔', '균형'],
#              13: ['아주', '압구정', '강남구', '힐링', '보고회'],
#              14: ['스포츠', '총장', '비선', '이화여대', '정유라'],
#              15: ['신진', '디자이너', '패션', '2017', '유진'],
#              16: ['은행', '대출', '금융', '계좌', '수수료'],
#              17: ['여러분', '언론', '공감', '라스베이거스', '가치'],
# ...

# %%
ctm.get_topics(10)
# Out:
# defaultdict(list,
#             {0: ['시장',
#               '나노',
#               '네이버',
#               '패널',
#               '삼성',
#               '서비스',
#               '부사장',
#               '클라우드',
#               '디스플레이',
#               '한성숙'],
#              1: ['영화',
#               '사랑',
#               '배우',
#               '때문',
#               '차태현',
#               '서현진',
#               '김유정',
#               '개봉',
#               '닥터',
#               '박보검'],
#              2: ['필리핀', '중국', '테르', '회담', '베이징', '분쟁', '주석', '에서', '미국', '정상'],
#              3: ['지상파',
#               '방송',
#               '방송사',
#               '가이드라인',
#               '산정',
#               '유료',
#               '협상',
#               '대가',
#               '재송',
#               '사업자'],
#              4: ['다운',
#               '재킷',
#               '제공',
#               '이벤트',
#               '소재',
#               '출시',
#               '아이템',
#               '스토어',
#               '플러스',
# ...

# %% [markdown]
# 위에서 출력한 토픽 번호는 pyLDAvis에서 할당한 토픽 번호와 일치하지 않으므로 주의합시다.
# 가령, 48번 토픽이었던 ['원유', '유가', '뉴욕', '오른', '연방', '마쳤', '서부', '달러', '51', '지수']가 아래의 PyLDAvis에서는 24번 토픽이 되었습니다.

# %%
import pyLDAvis as vis

lda_vis_data = ctm.get_ldavis_data_format(vocab, training_dataset, n_samples=10)

ctm_pd = vis.prepare(**lda_vis_data)
vis.display(ctm_pd)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
ctm.save(models_dir="./")
# Out:
# /usr/local/lib/python3.11/dist-packages/contextualized_topic_models/models/ctm.py:640: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn(

# %%
import torch
import numpy
import torch.serialization
from contextualized_topic_models.models.ctm import CombinedTM

# Add both numpy.ndarray and numpy.dtype to safe globals
torch.serialization.add_safe_globals([numpy.ndarray, numpy.dtype])

ctm2 = CombinedTM(bow_size=len(vocab), contextual_size=768, n_components=50, num_epochs=20)

with torch.serialization.safe_globals([numpy.ndarray, numpy.dtype]):
  ctm.load("./contextualized_topic_model_nc_50_tpm_0.0_tpv_0.98_hs_prodLDA_ac_(100, 100)_do_softplus_lr_0.2_mo_0.002_rp_0.99", epoch=19)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3892376222.py in <cell line: 0>()
#       2 import numpy
#       3 import torch.serialization
# ----> 4 from contextualized_topic_models.models.ctm import CombinedTM
#       5
#       6 # Add both numpy.ndarray and numpy.dtype to safe globals
#
# /usr/local/lib/python3.11/dist-packages/contextualized_topic_models/models/ctm.py in <module>
#       8 import torch
#       9 import wordcloud
# ---> 10 from scipy.special import softmax
#      11 from torch import optim
#      12 from torch.optim.lr_scheduler import ReduceLROnPlateau
#
# /usr/local/lib/python3.11/dist-packages/scipy/special/__init__.py in <module>
#     779
#     780 # Replace some function definitions from _ufuncs to add Array API support
# --> 781 from ._support_alternative_backends import (
# ...

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.24.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 50.5 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2025.7.1 requires numpy>=1.26, but you have numpy 1.24.4 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.24.4 which is incompatible.
# pymc 5.25.1 requires numpy>=1.25.0, but you have numpy 1.24.4 which is incompatible.
# blosc2 3.6.1 requires numpy>=1.26, but you have numpy 1.24.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# jaxlib 0.5.3 requires numpy>=1.25, but you have numpy 1.24.4 which is incompatible.
# ...

# %%
import torch
import numpy
import torch.serialization
from contextualized_topic_models.models.ctm import CombinedTM

# Monkey patch torch.load to always use weights_only=False
original_torch_load = torch.load
#torch.load = lambda *args, **kwargs: original_torch_load(*args, **kwargs, weights_only=False)

ctm2 = CombinedTM(bow_size=3000, contextual_size=768, num_epochs=100, n_components=50)
# Then load your model
ctm2.load(
    "./contextualized_topic_model_nc_50_tpm_0.0_tpv_0.98_hs_prodLDA_ac_(100, 100)_do_softplus_lr_0.2_mo_0.002_rp_0.99",
    epoch=19
)

# Restore original torch.load if needed
#torch.load = original_torch_load
# Out:
# /usr/local/lib/python3.11/dist-packages/contextualized_topic_models/models/ctm.py:669: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3140902366.py in <cell line: 0>()
#      10 ctm2 = CombinedTM(bow_size=3000, contextual_size=768, num_epochs=100, n_components=50)
#      11 # Then load your model
# ---> 12 ctm2.load(
#      13     "./contextualized_topic_model_nc_50_tpm_0.0_tpv_0.98_hs_prodLDA_ac_(100, 100)_do_softplus_lr_0.2_mo_0.002_rp_0.99",
#      14     epoch=19
#
# /usr/local/lib/python3.11/dist-packages/contextualized_topic_models/models/ctm.py in load(self, model_dir, epoch)
#     676         model_file = os.path.join(model_dir, epoch_file)
# ...

# %%
ctm.get_topic_lists(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3169457610.py in <cell line: 0>()
# ----> 1 ctm.get_topic_lists(5)
#
# NameError: name 'ctm' is not defined

# %% [markdown]
# 참고 자료 : https://github.com/MilaNLProc/contextualized-topic-models
