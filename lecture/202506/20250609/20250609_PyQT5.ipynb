# %%
# !pip install PyQt5
# Out:
# Collecting PyQt5
#   Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt5-sip<13,>=12.15 (from PyQt5)
#   Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl.metadata (536 bytes)
# Downloading PyQt5-5.15.11-cp38-abi3-manylinux_2_17_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 30.0 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.17-py3-none-manylinux2014_x86_64.whl (61.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 11.3 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (276 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 13.0 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
# Successfully installed PyQt5-5.15.11 PyQt5-Qt5-5.15.17 PyQt5-sip-12.17.0

# %%
from PyQt5.QtCore import QObject, pyqtSignal

class MyObject(QObject):
    data_ready = pyqtSignal(str)

    def process_data(self, data):
        processed_data = data.upper()
        self.data_ready.emit(processed_data)

def handle_data(data):
    print("Processed data:", data)

# Create objects
my_object = MyObject()

# Connect signal to slot
my_object.data_ready.connect(handle_data)

# Process data
my_object.process_data("hello world")
# Out:
# Processed data: HELLO WORLD
