# %%
import requests
import xml.etree.ElementTree as ET
import json
import xmltodict

open_api_url = "http://openapi.kepco.co.kr/service/EvInfoServiceV2/getEvSearchList"
#param list
#ServiceKey = "KNHvj%2FdXk6aVSlT0I0dBtuVLv1O5QfJHY6%2Be8rhlZrKq1cz%2BoNfQ0rYQ7f0KIADcrMxnhTUKj5tVWAXv3HzZpQ%3D%3D"
ServiceKey = "KNHvj/dXk6aVSlT0I0dBtuVLv1O5QfJHY6+e8rhlZrKq1cz+oNfQ0rYQ7f0KIADcrMxnhTUKj5tVWAXv3HzZpQ=="
pageNo = 1
numOfRows = 10
addr = ''

params = {
    "ServiceKey":ServiceKey,
    "pageNo":pageNo,
    "numOfRows":numOfRows,
    "addr":addr
}

#response = requests.get(open_api_url, params=params)

print(response.text)
root = ET.fromstring(response.text)
header = root.find("header")

print("resultCode:", header.find("resultCode").text)
print("resultMsg:", header.find("resultMsg").text)


   doc = xmltodict.parse(f.read())

json_data = json.loads(json.dumps(doc))
print(json_data)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>99</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>
# resultCode: 99
# resultMsg: SERVICE KEY IS NOT REGISTERED ERROR.

# %%
import requests
from urllib import parse

url = "http://openapi.kepco.co.kr/service/EvInfoServiceV2/getEvSearchList"
api_key_utf8 = "KNHvj%2FdXk6aVSlT0I0dBtuVLv1O5QfJHY6%2Be8rhlZrKq1cz%2BoNfQ0rYQ7f0KIADcrMxnhTUKj5tVWAXv3HzZpQ%3D%3D"
api_key_decode = parse.unquote(api_key_utf8)
print(api_key_decode)

params = {
    "ServiceKey": api_key_decode,
    "pageNo": 1,
    "numOfRows": 5
}

response = requests.get(url, params=params)
print(response.text)
# Out:
# KNHvj/dXk6aVSlT0I0dBtuVLv1O5QfJHY6+e8rhlZrKq1cz+oNfQ0rYQ7f0KIADcrMxnhTUKj5tVWAXv3HzZpQ==
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>99</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>

# %%
# !pip install xmltodict
