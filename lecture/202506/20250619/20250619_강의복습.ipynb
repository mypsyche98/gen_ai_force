# %%
# page6

def bubble_sort(arr):
  n = len(arr)
  for i in range(n):
    for j in range(0, n-i-1):
      if arr[j] > arr[j+1]:
        arr[j], arr[j+1] = arr[j+1], arr[j]
  return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", bubble_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 12, 22, 25, 34, 64, 90]

# %%
# page7

def optimized_bubble_sort(arr):
  n = len(arr)
  for i in range(n):
    swapped = False
    for j in range(0, n-i-1):
      if arr[j] > arr[j+1]:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        swapped = True
    if not swapped:
      break
  return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", optimized_bubble_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 12, 22, 25, 34, 64, 90]

# %%
# page10

def selection_sort(arr):
  n = len(arr)
  for i in range(n):
    min_idx = 1
    for j in range(i+1, n):
      if arr[j] < arr[min_idx]:
        min_idx = j
    arr[i], arr[min_idx] = arr[min_idx], arr[i]
  return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", selection_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 90, 12, 22, 25, 34, 64]

# %%
# page13

def insertion_sort(arr):
  for i in range(1, len(arr)):
    key = arr[i]
    j = i-1
    while j >= 0 and key < arr[j]:
      arr[j+1] = arr[j]
      j -= 1
    arr[j+1] = key
  return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", insertion_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 12, 22, 25, 34, 64, 90]

# %%
# page15,16

def heapify(arr, n, i):
  largest = i
  l = 2 * i + 1
  r = 2 * i + 2

  if l < n and arr[l] > arr[largest]:
    largest = l

  if r < n and arr[r] > arr[largest]:
    largest = r

  if largest != i:
    arr[i], arr[largest] = arr[largest], arr[i]

    heapify(arr, n, largest)

def heap_sort(arr):
  n = len(arr)

  for i in range(n//2-1, -1, -1):
    heapify(arr, n, i)

  for i in range(n-1, 0, -1):
    arr[i], arr[0] = arr[0], arr[i]
    heapify(arr, i, 0)

  return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", heap_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 12, 22, 25, 34, 64, 90]

# %%
# page20

def quick_sort(arr):
  if len(arr) <= 1:
    return arr

  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]

  return quick_sort(left) + middle + quick_sort(right)

arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", quick_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 12, 22, 25, 34, 64, 90]

# %%
# page25,26

def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr)//2
    L = arr[:mid]
    R = arr[mid:]

    merge_sort(L)
    merge_sort(R)

    i = j = k = 0

    while i < len(L) and j < len(R):
      if L[i] < R[j]:
        arr[k] = L[i]
        i += 1
      else:
        arr[k] = R[j]
        j += 1
      k += 1

    while i < len(L):
      arr[k] = L[i]
      i += 1
      k += 1

    while j < len(R):
      arr[k] = R[j]
      j += 1
      k += 1
  return arr


arr = [64, 34, 25, 12, 22, 11, 90]
print("Org   =", arr)
print("Sorted=", merge_sort(arr))
# Out:
# Org   = [64, 34, 25, 12, 22, 11, 90]
# Sorted= [11, 12, 22, 25, 34, 64, 90]

# %%
# page30

def counting_sort(arr, exp1):
  n = len(arr)
  output = [0] * n
  count = [0] * (10)
  for i in range(n):
    index = arr[i] // exp1
    count[index % 10] += 1

  for i in range(1, 10):
    count[i] += count[i - 1]

  i = n - 1
  while i >= 0 :
    index = arr[i] // exp1
    output[count[index % 10] -1] = arr[i]
    count[index % 10] -= 1
    i -= 1

  for i in range(n):
    arr[i] = output[i]

def radix_sort(arr):
  max1 = max(arr)
  exp = 1
  while max1 // exp > 0:
    counting_sort(arr, exp)
    exp *= 10
  return arr


arr = [170,45,75,90,802,24,2,66]
print("Org   =", arr)
print("Sorted=", radix_sort(arr))
# Out:
# Org   = [170, 45, 75, 90, 802, 24, 2, 66]
# Sorted= [2, 24, 45, 66, 75, 90, 170, 802]

# %%
# page34

def counting_sort(arr):
  max_val = max(arr)

  count_arr = [0] * (max_val+1)

  for num in arr:
    count_arr[num] += 1

  for i in range(1, len(count_arr)):
    count_arr[i] += count_arr[i-1]

  output_arr = [0] * len(arr)

  i = len(arr) - 1
  while i >= 0 :
    output_arr[count_arr[arr[i]] - 1] = arr[i]
    count_arr[arr[i]] -= 1
    i -= 1

  for i in range(len(arr)):
    arr[i] = output_arr[i]

  return arr

arr = [170,45,75,90,802,24,2,66]
print("Org   =", arr)
print("Sorted=", counting_sort(arr))
# Out:
# Org   = [170, 45, 75, 90, 802, 24, 2, 66]
# Sorted= [2, 24, 45, 66, 75, 90, 170, 802]

# %%
# page38

my_list = [3, 1, 4, 1, 5, 9, 2]
print("mylist=",my_list)
sorted_list = sorted(my_list)
print("sorted=", sorted_list)
print()

people = [{'name':'John', 'age':45}, {'name':'Diane', 'age':35}]
print("people=",people)
sorted_people = sorted(people, key=lambda x : x['age'])
print("sorted=",sorted_people)
# Out:
# mylist= [3, 1, 4, 1, 5, 9, 2]
# sorted= [1, 1, 2, 3, 4, 5, 9]
#
# people= [{'name': 'John', 'age': 45}, {'name': 'Diane', 'age': 35}]
# sorted= [{'name': 'Diane', 'age': 35}, {'name': 'John', 'age': 45}]

# %%
# page39

my_list = [3, 1, 4, 1, 5, 9, 2]
print("mylist=",my_list)
my_list.sort()
print("sorted=", my_list)
print()

people = [{'name':'John', 'age':45}, {'name':'Diane', 'age':35}]
print("people=",people)
people.sort(key=lambda x : x['age'])
print("sorted=",people)
# Out:
# mylist= [3, 1, 4, 1, 5, 9, 2]
# sorted= [1, 1, 2, 3, 4, 5, 9]
#
# people= [{'name': 'John', 'age': 45}, {'name': 'Diane', 'age': 35}]
# sorted= [{'name': 'Diane', 'age': 35}, {'name': 'John', 'age': 45}]

# %%
# page44

def binary_search_recursive(arr, target, left, right):
  if left > right:
    return False

  mid = (left + right) // 2
  if arr[mid] == target:
    return True
  elif arr[mid] < target:
    return binary_search_recursive(arr, target, mid+1, right)
  else:
    return binary_search_recursive(arr, target, left, mid-1)

arr = [2, 24, 45, 66, 75, 90, 170, 802]
print("find 802=", binary_search_recursive(arr, 802, 0, len(arr)-1))
print("find 76=", binary_search_recursive(arr, 76, 0, len(arr)-1))
# Out:
# find 802= True
# find 76= False

# %%
# page45

def binary_search_iterative(arr, target):
  left, right = 0, len(arr) - 1

  while left <= right:
    mid = (left + right) // 2
    if arr[mid] == target:
      return True
    elif arr[mid] < target:
      left = mid+1
    else:
      right = mid-1

  return False

arr = [2, 24, 45, 66, 75, 90, 170, 802]
print("find 802=", binary_search_iterative(arr, 802))
print("find 76=", binary_search_iterative(arr, 76))
# Out:
# find 802= True
# find 76= False

# %%
# page52,53

graph = {
    'A': ['B','C'],
    'B': ['A','D','E'],
    'C': ['A','F'],
    'D': ['B'],
    'E': ['B','F'],
    'F': ['C','E']
}

from collections import deque

def bfs(graph, start):
  visited = set()
  queue = deque([start])

  while queue:
    vertex = queue.popleft()
    if vertex not in visited:
      visited.add(vertex)
      print(vertex, end=' ')
      queue.extend([i for i in graph[vertex] if i not in visited])

bfs(graph, 'A')
# Out:
# A B C D E F

# %%
# page57,58

graph = {
    'A': ['B','C'],
    'B': ['A','D','E'],
    'C': ['A','F'],
    'D': ['B'],
    'E': ['B','F'],
    'F': ['C','E']
}

visited = {key : False for key in graph.keys()}

def dfs_recursive(graph, visited, node):
  if not visited[node]:
    print(node, end=" ")
    visited[node] = True
    for neighbour in graph[node]:
      dfs_recursive(graph, visited, neighbour)

print("DFS 방문순서")
dfs_recursive(graph, visited, 'A')
# Out:
# DFS 방문순서
# A B D E F C

# %%
# page59

graph = {
    'A': ['B','C'],
    'B': ['A','D','E'],
    'C': ['A','F'],
    'D': ['B'],
    'E': ['B','F'],
    'F': ['C','E']
}

def dfs_stack(graph, start):
  visited = set()
  stack = [start]

  while stack:
    node = stack.pop()
    if node not in visited:
      print(node, end=" ")
      visited.add(node)
      stack.extend([x for x in graph[node] if x not in visited])

print("DFS 방문순서 (스택)")
dfs_stack(graph, 'A')
# Out:
# DFS 방문순서 (스택)
# A C F E B D

# %%
# page63

import heapq

def dijkstra(graph, start):
  distances = {vertex: float('infinity') for vertex in graph}
  #print(distances)
  distances[start] = 0
  priority_queue = [(0, start)]

  while priority_queue:
    current_distance, current_vertex = heapq.heappop(priority_queue)
    #print(current_vertex, current_distance)

    if current_distance > distances[current_vertex]:
      continue

    for neighbour, weight in graph[current_vertex]:
      distance = current_distance + weight

      if distance < distances[neighbour]:
        distances[neighbour] = distance
        heapq.heappush(priority_queue, (distance, neighbour))

  return distances

graph = {
    "A": [("B", 1), ("C", 4), ("D", 5)],
    "B": [("A", 1), ("D", 2)],
    "C": [("A", 4), ("D", 4), ("E", 3)],
    "D": [("A", 5), ("B", 2), ("C", 4), ("F", 3)],
    "E": [("C", 3), ("F", 2)],
    "F": [("D", 3), ("E", 2)]
}

print("dijkstra=", dijkstra(graph, "A"))
# Out:
# dijkstra= {'A': 0, 'B': 1, 'C': 4, 'D': 3, 'E': 7, 'F': 6}

# %%
# page72,73

class UnionFind:
  def __init__(self, size):
    self.root = [i for i in range(size)]
    self.rank = [1] * size

  def find(self, x):
    if x == self.root[x]:
      return x
    self.root[x] = self.find(self.root[x])
    return self.root[x]

  def union(self, x, y):
    rootX = self.find(x)
    rootY = self.find(y)
    if rootX != rootY:
      if self.rank[rootY] > self.rank[rootY]:
        self.root[rootY] = rootX
      elif self.rank[rootX] < self.rank[rootY]:
        self.root[rootX]
      else:
        self.root[rootY] = rootX
        self.rank[rootX] += 1

  def connected(self, x, y):
    return self.find(x) == self.find(y)

if __name__ == '__main__':
  uf = UnionFind(10)
  uf.union(1,2)
  uf.union(2,3)
  uf.union(4,5)
  uf.union(6,7)
  uf.union(5,6)
  uf.union(3,7)

  print(uf.connected(1,5))
# Out:
# True
